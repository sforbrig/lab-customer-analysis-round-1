# %%
# in case of new notebook, use the commented code to load the data:

import pandas as pd

file1 = pd.read_csv('./file1.csv')
file2 = pd.read_csv('./file2.txt', sep = '\t')
file3 = pd.read_excel('./file3.xlsx', engine="openpyxl")
file4 = pd.read_excel('./file4.xlsx', engine="openpyxl")
column_names = file1.columns
donors = pd.DataFrame(columns=column_names)
donors = pd.concat([file1,file2,file3,file4], axis=0)
cols = []
for colname in donors.columns:
    cols.append(colname.lower())
donors.columns = cols
donors = donors.rename(columns={'controln':'id',
                                'hv1':'median_home_val', 
                                'ic1':'median_household_income'})
donors['median_home_val'] =  pd.to_numeric(donors['median_home_val'], errors='coerce')
donors['ic5'] =  pd.to_numeric(donors['ic5'], errors='coerce')
donors = donors.drop_duplicates()

donors.shape
# Out:
# (4001, 17)

# %%
donors.dtypes
#donors
# Out:
# id                           int64
# state                       object
# gender                      object
# median_home_val            float64
# median_household_income      int64
# ic4                        float64
# hvp1                         int64
# ic5                        float64
# pobc1                        int64
# pobc2                        int64
# ic2                        float64
# ic3                          int64
# avggift                    float64
# tcode                        int64
# dob                          int64
# domain                      object
# target_d                   float64
# dtype: object

# %%
donors.isna().sum()
# Out:
# id                           0
# state                        0
# gender                     133
# median_home_val             10
# median_household_income      0
# ic4                          1
# hvp1                         0
# ic5                          6
# pobc1                        0
# pobc2                        0
# ic2                          1
# ic3                          0
# avggift                      0
# tcode                        0
# dob                          0
# domain                       0
# target_d                     0
# dtype: int64

# %%
donors.isna().sum()
round(donors.isna().sum()/len(donors),4)*100  # shows the percentage of null values in a column
nulls_df = pd.DataFrame(round(donors.isna().sum()/len(donors),4)*100)
nulls_df
nulls_df = nulls_df.reset_index()
nulls_df
nulls_df.columns = ['header_name', 'percent_nulls']
nulls_df
# Out:
#                 header_name  percent_nulls
# 0                        id           0.00
# 1                     state           0.00
# 2                    gender           3.32
# 3           median_home_val           0.25
# 4   median_household_income           0.00
# 5                       ic4           0.02
# 6                      hvp1           0.00
# 7                       ic5           0.15
# 8                     pobc1           0.00
# 9                     pobc2           0.00
# 10                      ic2           0.02
# 11                      ic3           0.00
# 12                  avggift           0.00
# 13                    tcode           0.00
# 14                      dob           0.00
# 15                   domain           0.00
# 16                 target_d           0.00

# %%
columns_drop = nulls_df[nulls_df['percent_nulls']>3]['header_name']  # dummy case with 3
print(columns_drop.values)
#donors = donors.drop(columns_drop, axis=1)  # drop a list of columns DO NOT RUN THIS
#donors = donors.drop(['gender'], axis=1)  # drop a single column DO NOT RUN THIS

# %%
# Replacing/imputing null values
donors[donors['gender'].isna()==True].head(60) # checking rows that are null based on a specific column

# %%
# drop rows that have null values (only if there are very few)
donors = donors[donors['ic2'].isna()==False] # Since these nulls are not a lot, we can filter them

donors.isna().sum()

# %%
# impute a value for the missing value (fill in a value that we choose or calculate)
# import numpy
import numpy as np
mean_median_home_value = donors['median_home_val'].mean()
mean_median_home_value
donors['median_home_val'] = donors['median_home_val'].fillna(mean_median_home_value)

# %%
donors.isna().sum()
# Out:
# id                           0
# state                        0
# gender                     133
# median_home_val             10
# median_household_income      0
# ic4                          1
# hvp1                         0
# ic5                          6
# pobc1                        0
# pobc2                        0
# ic2                          1
# ic3                          0
# avggift                      0
# tcode                        0
# dob                          0
# domain                       0
# target_d                     0
# dtype: int64

# %%
#Activity 1

# %%
donors = donors[donors['ic4'].isna()==False]
donors.isna().sum()
# Out:
# id                           0
# state                        0
# gender                     133
# median_home_val             10
# median_household_income      0
# ic4                          0
# hvp1                         0
# ic5                          6
# pobc1                        0
# pobc2                        0
# ic2                          1
# ic3                          0
# avggift                      0
# tcode                        0
# dob                          0
# domain                       0
# target_d                     0
# dtype: int64

# %%
median_ic5 = donors['ic5'].median()
median_ic5
donors['ic5'] = donors['ic5'].fillna(median_ic5)

# %%
donors.isna().sum()
# Out:
# id                           0
# state                        0
# gender                     133
# median_home_val             10
# median_household_income      0
# ic4                          0
# hvp1                         0
# ic5                          0
# pobc1                        0
# pobc2                        0
# ic2                          1
# ic3                          0
# avggift                      0
# tcode                        0
# dob                          0
# domain                       0
# target_d                     0
# dtype: int64

# %%
donors.head(60)
# Out:
#         id state  gender  median_home_val  median_household_income    ic4  \
# 0    44060    FL       M              NaN                      392  520.0
# 1    96093    IL       M            537.0                      365  473.0
# 2    43333    FL       F            725.0                      301  436.0
# 3    21885    NC       M              NaN                      401  413.0
# 4   190108    FL       F            995.0                      252  348.0
# 5   100640    IL       M            764.0                      457  501.0
# 6    18581    NC  female            775.0                      318  419.0
# 7   119038    TX       M            890.0                      519  560.0
# 8   173223    CA       F              NaN                      184  250.0
# 9   157988    CA       F              NaN                      593  617.0
# 10  141720    NV       F           1569.0                      673  781.0
# 11  186272    CA       F           3515.0                      521  588.0
# 12  154301  Cali       F           1026.0                      459  496.0
# 13  189722    AP    Male              0.0                        0    0.0
# 14  188304    KS       F            376.0                      263  316.0
# 15   73699    MI     NaN            890.0                      463  523.0
# 16   31977    FL       F           1513.0                      521  702.0
# 17   44336    FL       F            948.0                      330  411.0
# 18  127823    TX       F            258.0                       64   74.0
# 19  150739    CA       U           1951.0                      556  625.0
# 21  114721    OK     NaN           1040.0                      472  656.0
# 22  111795    AR     NaN            603.0                      208  341.0
# 23   64480    IN       F            526.0                      277  370.0
# 24   87259    MT       M            717.0                      302  432.0
# 25  115823    TX       M           1011.0                      593  650.0
# 26   95701    IL       M           1063.0                      255  317.0
# 27    5172    IL       M            291.0                      136  212.0
# 28  152486    CA       M           1538.0                      271  393.0
# 29  153880    WI       F            592.0                      244  392.0
# 30  101855    MO       M            871.0                      340  416.0
# 31   62932    IN       M            403.0                      174  264.0
# 32  125930    TX       F            715.0                      339  396.0
# 33  173653    HI       F           2346.0                      420  503.0
# 34   11011    FL       M            559.0                      232  269.0
# 35  116894    TX       M              NaN                      368  531.0
# 25      15.0
# 26       5.0
# 27      10.0
# 28       5.0
# 29       5.0
# 30      10.0
# 31      10.0
# 32       7.5
# 33      21.0
# 34      20.0
# 35      20.0
# 36      15.0
# 37      25.0
# 38      16.0
# 39      10.0
# 40       5.0
# 41      15.0
# 42      11.0
# 43       5.0
# 44      35.0
# 45      10.0
# 46      10.0
# 47      15.0
# 48      25.0
# 49      10.0
# 50       6.0
# 51      15.0
# 52      18.0
# 53      24.0
# 54      14.0
# 55      20.0
# 56      21.0
# 57      15.0
# 58      41.0
# 59      20.0
# 60       5.0

# %%
#End of Activity 1

# %%
# Replacing null values for categorical variables
donors['gender'].unique()
donors['gender'].value_counts()

donors['gender'].value_counts(dropna=False)
#len(donors[donors['gender'].isna()==True])  # number of missing values

# %%
# use most common value to fillna
donors['gender'] = donors['gender'].fillna('F')
len(donors[donors['gender'].isna()==True]) # now this number is 0

# %%
# Exporting this processed data to a csv
donors.to_csv('merged_clean_ver1.csv') # you can find this file inside files_for_lesson_and_activities folder

# %%
# lambda expressions

def add_two(x):
    #some code
    return x+2

# def do_something(lst,fun):
#      #some code
#      return result

# do_something([1,2,3],add_two)

add_two(4)

# %%
y = lambda x: x+2
y(2)

square = lambda x: x*x
square(4)

addition = lambda x,y : x+y
addition(1,5)

# lst = [1,2,3,4,5,6,7,8,10]
# new_list = []
# for item in lst:
#     new_list.append(square(item))
# new_list

# new_list = [square(item) for item in lst] # list comprehension
# print(new_list)

# # new_list = [square(item) for item in lst if item%2==0]

# %%
#Activity 2
a2 = pd.read_csv('./df_final_web_data_pt_1.csv')
a2
# Out:
#         Unnamed: 0  client_id             visitor_id  \
# 0                0    9988021   580560515_7732621733
# 1                1    9988021   580560515_7732621733
# 2                2    9988021   580560515_7732621733
# 3                3    9988021   580560515_7732621733
# 4                4    9988021   580560515_7732621733
# ...            ...        ...                    ...
# 343136      343136    2443347  465784886_73090545671
# 343137      343137    2443347  465784886_73090545671
# 343138      343138    2443347  465784886_73090545671
# 343139      343139    2443347  465784886_73090545671
# 343140      343140    2443347  465784886_73090545671
#
#                             visit_id process_step      date_time
# 0       781255054_21935453173_531117       step_3  4/17/17 15:27
# 1       781255054_21935453173_531117       step_2  4/17/17 15:26
# 2       781255054_21935453173_531117       step_3  4/17/17 15:19
# 3       781255054_21935453173_531117       step_2  4/17/17 15:19
# 4       781255054_21935453173_531117       step_3  4/17/17 15:18
# ...                              ...          ...            ...
# 343136  136329900_10529659391_316129      confirm  3/31/17 15:15
# 343137  136329900_10529659391_316129       step_3  3/31/17 15:14
# 343138  136329900_10529659391_316129       step_2  3/31/17 15:12
# 343139  136329900_10529659391_316129       step_1  3/31/17 15:11
# 343140  136329900_10529659391_316129        start  3/31/17 15:10
#
# [343141 rows x 6 columns]

# %%
a2.isna().sum()
# Out:
# Unnamed: 0      0
# client_id       0
# visitor_id      0
# visit_id        0
# process_step    0
# date_time       0
# dtype: int64

# %%
a2 = a2.drop(['Unnamed: 0'], axis=1)
a2.head()
# Out:
#    client_id            visitor_id                      visit_id process_step  \
# 0    9988021  580560515_7732621733  781255054_21935453173_531117       step_3
# 1    9988021  580560515_7732621733  781255054_21935453173_531117       step_2
# 2    9988021  580560515_7732621733  781255054_21935453173_531117       step_3
# 3    9988021  580560515_7732621733  781255054_21935453173_531117       step_2
# 4    9988021  580560515_7732621733  781255054_21935453173_531117       step_3
#
#        date_time
# 0  4/17/17 15:27
# 1  4/17/17 15:26
# 2  4/17/17 15:19
# 3  4/17/17 15:19
# 4  4/17/17 15:18

# %%
# Refer to the file files_for_activities/merged_clean_ver1.csv for this exercise.

#1 Import the data from merged_clean_ver1.csv as a dataframe. There would be a column with the sequence of numbers (to the left of column id). Drop that column(s).

# %%
# 2 Check the column state for null values. Replace those null values with the state that is represented largest number of times in that column
donors['state'].value_counts(dropna=True)
len(donors[donors['state'].isna()==True])
# Out:
# 0

# %%
# 3.1 Create a simple lambda expression to add three numbers. Take those three numbers as input from the user.

# %%
# 3.2 Define a list as lst = [1,2,3,4,5,6,7,8,10]. 
#     Write a lambda expression to find the cube of a number.
#     Use that lambda expression to find the cube of every number in the list. 
#     Define a list comprehension for this question

# %%
#End of Activity 2
donors.columns
# Out:
# Index(['id', 'state', 'gender', 'median_home_val', 'median_household_income',
#        'ic4', 'hvp1', 'ic5', 'pobc1', 'pobc2', 'ic2', 'ic3', 'avggift',
#        'tcode', 'dob', 'domain', 'target_d'],
#       dtype='object')

# %%
# map functions
list(map(print, donors.columns))
#donors.columns = list(map(lambda x: x.lower(), donors.columns)) # we did this with a for loop earlier
# # donors
donors['gender'].unique() # check the unique values in the column
donors['gender'] = list(map(lambda x: x.upper(), donors['gender']))
donors['gender'].unique()

# %%
donors['gender'].unique()  # check the unique elements in the column
# Now define a function to clean the column
def clean(x):
    if x in ['M', 'MALE']:
        return 'Male'
    elif x.startswith('F'):
        return 'Female'
    else:
        return 'U'

donors['gender'] = list(map(clean, donors['gender']))
donors['gender'].unique()  # To check the results again
donors

# %%
#Activity 3



# End of Activity 3

# %%
# Examples of working with datetime format:

file = pd.read_csv('df_final_web_data_pt_1.csv')
file.dtypes

file['date_time'] = pd.to_datetime(file['date_time'], errors='coerce')
file.dtypes

# %%
file['date_time'][0].day
# file['date_time'][0].month
# file['date_time'][0].year
# file['date_time'][0].isoweekday()  # Returns 1 for Monday and so on

# file['date_time'][0].time()
# file['date_time'][0].isoweekday()
# file['date_time'][0].isoformat()
# file['date_time'][0].strftime(format='%d-%m-%Y')
file['date_time'][0].strftime(format="%A %d. %B %Y")

# %%
import time
from datetime import date

today = date.today()
today

# time.localtime(time.time())
# time.gmtime(time.time())

# %%
# Examples of working with string functions

string = " I am learning  data  analysis at Ironhack  . It is  super easy "
string.lower
string.upper()
'34'.isdigit() # does not work with decimal numbers
str2 = '42'
str2.isdigit()
string = string.lstrip()
string.rstrip()
string.split()
string.split('.')
string.replace('%', '')

# %%
#Acticity 4
# Create a user-defined method to clean the column state in the dataframe.
# Use string functions to standardize the states to uppercase and use the strip function to clean the strings as well.

# %%
#End Activity 4

# %%
# Exporting this processed data to a csv
donors.to_csv('merged_clean_ver2.csv')
